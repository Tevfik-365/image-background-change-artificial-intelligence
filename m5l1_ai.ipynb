# %% [markdown]
# <a href="https://colab.research.google.com/github/Tevfik-365/zeka/blob/main/m5l1_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread("/content/zeka.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
# !pip install rembg

# %%
from rembg import remove
input_path = "/content/zeka.png"
output_path = "akıl.png"
with open (input_path, "rb") as i:
    with open(output_path, "wb") as o:
        input = i.read()
        output  = remove(input)
        o.write(output)

# %%
import numpy as np

def change_back(background, img):

    x, y = 0, 0
    background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_AREA)
    res = np.copy(background)
    place = res[y: y + img.shape[0], x: x + img.shape[1]]
    a = img[..., 3:].repeat(3, axis=2).astype('uint16')
    place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255
    return res

# %%
import cv2
image = cv2.imread("/content/akıl.png",cv2.IMREAD_UNCHANGED)
back = cv2.imread("/content/back.jpeg")
result = change_back(back,image)
cv2.imwrite("son.jpeg", result)
# Out:
# True

# %%
import cv2

# %%
image = cv2.imread("/content/son.jpeg")

# %%
text = "Yapay zeka o kadar gelisti ki, yakinda tost makinesi bile bize akil verecek!"
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1
color = (255, 255, 255)

thickness = 2

# %%
image_with_text = cv2.putText(image, text, (50, 50), font, font_scale, color, thickness, cv2.LINE_AA)

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(image_with_text)
cv2.imwrite('mizah.jpeg', image_with_text)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
# True
